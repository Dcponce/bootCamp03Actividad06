# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os plt.style.use('seaborn-v0_8-colorblind')
# %matplotlib inline
from data_exploration import explore

# %%
#Read the dataset

# %%
data = pd.read_csv('./data/bank-additional-full.csv', sep=';')

# %%
data.head(3)
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          93.994          -36.4      4.857       5191.0  no
# 1          93.994          -36.4      4.857       5191.0  no
# 2          93.994          -36.4      4.857       5191.0  no
#
# [3 rows x 21 columns]

# %%
#Tipos de datos por columna

# %%
str_var_list, num_var_list, all_var_list = explore.get_dtypes(data=data)

# %%
print(str_var_list) # string type
print(num_var_list) # numeric type
print(all_var_list) # all
# Out:
# ['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'day_of_week', 'poutcome', 'y']
# ['age', 'duration', 'campaign', 'pdays', 'previous', 'emp.var.rate', 'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed']
# ['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'day_of_week', 'poutcome', 'y', 'age', 'duration', 'campaign', 'pdays', 'previous', 'emp.var.rate', 'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed']

# %%
#General data description

# %%
explore.describe(data=data,output_path=r'./output/')
# Out:
# result saved at: ./output/describe.csv
#                 age     job  marital          education default housing  \
# count   41188.00000   41188    41188              41188   41188   41188
# unique          NaN      12        4                  8       3       3
# top             NaN  admin.  married  university.degree      no     yes
# freq            NaN   10422    24928              12168   32588   21576
# mean       40.02406     NaN      NaN                NaN     NaN     NaN
# std        10.42125     NaN      NaN                NaN     NaN     NaN
# min        17.00000     NaN      NaN                NaN     NaN     NaN
# 25%        32.00000     NaN      NaN                NaN     NaN     NaN
# 50%        38.00000     NaN      NaN                NaN     NaN     NaN
# 75%        47.00000     NaN      NaN                NaN     NaN     NaN
# max        98.00000     NaN      NaN                NaN     NaN     NaN
#
# ...

# %%
#Gráfico de barras

# %%
explore.discrete_var_barplot(x='job',y='age',data=data,output_path='./output/')
# Out:
# Image saved at ./output/Barplot_job_age.png

# %%
#Bloxpot

# %%
explore.discrete_var_boxplot(x='marital',y='age',data=data,output_path='./output/')
# Out:
# Image saved at ./output/Boxplot_marital_age.png

# %%
#Continuous variable distplot

# %%
explore.continuous_var_distplot(x=data['age'],output_path='./output/')
# Out:
# C:\Users\David Cordova\Desktop\Curso python\proyecto_ai\bootCamp03\actividad06\data_exploration\explore.py:138: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(a=x,kde=False,bins=bins)
# Image saved at ./output/Distplot_age.png

# %%
#Diagrama de dispersión

# %%
explore.scatter_plot(x=data.age,y=data.marital,data=data,output_path='./output/')
# Out:
# Image saved at ./output/Scatter_plot_age_marital.png

# %%
explore.correlation_plot(data=data,output_path='./output/')
# Out:
# Image saved at ./output/Corr_plot.png
