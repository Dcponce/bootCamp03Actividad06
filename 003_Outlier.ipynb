# %%
import pandas as pd
import numpy as np
# import seaborn as sns
# import matplotlib.pyplot as plt
import os
# plt.style.use('seaborn-colorblind')
# %matplotlib inline
from feature_cleaning import outlier as ot
import warnings
warnings.filterwarnings("ignore")

# %%
#Leer dataset

# %%
data = pd.read_csv('./data/bank-additional-full.csv', sep=';')
data.head(3)
print(data.shape)
# Out:
# (41188, 21)

# %%
pd.Series(data.duration.unique()).sort_values()
# Out:
# 939        0
# 1436       1
# 1391       2
# 666        3
# 546        4
#         ...
# 997     3631
# 1184    3643
# 1535    3785
# 1362    4199
# 1383    4918
# Length: 1544, dtype: int64

# %%
# Detectar por límite arbitrario

# %%
index,para = ot.outlier_detect_arbitrary(data=data,col='duration',upper_fence=300,lower_fence=5)
print('Límite superior:',para[0],'\nLímite inferior:',para[1])
# Out:
# Num of outlier detected: 11227
# Proportion of outlier detected 0.2725793920559386
# Límite superior: 300
# Límite inferior: 5

# %%
data.loc[index,'duration'].sort_values()
# Out:
# 28063       0
# 6251        0
# 33015       0
# 23031       0
# 40554       1
#          ...
# 7727     3631
# 13820    3643
# 40537    3785
# 22192    4199
# 24091    4918
# Name: duration, Length: 11227, dtype: int64

# %%
# Metodo IQR

# %%
index,para = ot.outlier_detect_IQR(data=data,col='duration',threshold=5)
print('Upper bound:',para[0],'\nLower bound:',para[1])
# Out:
# Num of outlier detected: 276
# Proportion of outlier detected 0.006700980868214043
# Upper bound: 1404.0
# Lower bound: -983.0

# %%
data.loc[index,'duration'].sort_values()
# Out:
# 40672    1405
# 39914    1407
# 3829     1408
# 21984    1408
# 16234    1408
#          ...
# 7727     3631
# 13820    3643
# 40537    3785
# 22192    4199
# 24091    4918
# Name: duration, Length: 276, dtype: int64

# %%
# Método de media y desviación estándar

# %%
index,para = ot.outlier_detect_mean_std(data=data,col='duration',threshold=3)
print('Límite superior:',para[0],'\nLímite inferior:',para[1])
# Out:
# Num of outlier detected: 861
# Proportion of outlier detected 0.020904146838885113
# Upper bound: 1036.1227567065391
# Lower bound: -519.5527363122494

# %%
data.loc[index,'duration'].sort_values()
# Out:
# 17612    1037
# 23636    1037
# 16326    1037
# 20756    1038
# 28604    1038
#          ...
# 7727     3631
# 13820    3643
# 40537    3785
# 22192    4199
# 24091    4918
# Name: duration, Length: 861, dtype: int64

# %%
# metodo MAD

# %%
index = ot.outlier_detect_MAD(data=data,col='duration',threshold=3.5)
# Out:
# Num of outlier detected: 2739
# Proportion of outlier detected 0.06649995144216762

# %%
# Imputación con valor arbitrario

# %%
index,para = ot.outlier_detect_arbitrary(data=data,col='duration',upper_fence=300,lower_fence=5)
print('Límite superior:',para[0],'\nLímite inferior:',para[1])
# Out:
# Num of outlier detected: 11227
# Proportion of outlier detected 0.2725793920559386
# Límite superior: 300
# Límite inferior: 5

# %%
data[255:275]
# Out:
#      age            job   marital          education  default  housing  \
# 255   53       services   married        high.school       no      yes
# 256   58    blue-collar   married           basic.9y  unknown      yes
# 257   45     management   married           basic.9y       no       no
# 258   43     technician   married            unknown       no      yes
# 259   33         admin.   married        high.school       no       no
# 260   33         admin.   married        high.school       no       no
# 261   27    blue-collar    single           basic.6y       no  unknown
# 262   42     technician   married        high.school       no       no
# 263   43         admin.  divorced           basic.9y       no       no
# 264   42         admin.   married  university.degree       no       no
# 265   27    blue-collar    single           basic.6y       no       no
# 266   34  self-employed    single  university.degree       no      yes
# ...

# %%
data2 = ot.impute_outlier_with_arbitrary(data=data,outlier_index=index,
                                         value=-999,col=['duration'])
data2[255:275]
# Out:
#      age            job   marital          education  default  housing  \
# 255   53       services   married        high.school       no      yes
# 256   58    blue-collar   married           basic.9y  unknown      yes
# 257   45     management   married           basic.9y       no       no
# 258   43     technician   married            unknown       no      yes
# 259   33         admin.   married        high.school       no       no
# 260   33         admin.   married        high.school       no       no
# 261   27    blue-collar    single           basic.6y       no  unknown
# 262   42     technician   married        high.school       no       no
# 263   43         admin.  divorced           basic.9y       no       no
# 264   42         admin.   married  university.degree       no       no
# 265   27    blue-collar    single           basic.6y       no       no
# 266   34  self-employed    single  university.degree       no      yes
# ...

# %%
# Windsorization
# Codificación superior e inferior (limitando el máximo de una distribución a un valor arbitrario, y viceversa)

# %%
index,para = ot.outlier_detect_arbitrary(data,'duration',300,5)
print('Límite superior:',para[0],'\nLímite inferior:',para[1])
# Out:
# Num of outlier detected: 11227
# Proportion of outlier detected 0.2725793920559386
# Límite superior: 300
# Límite inferior: 5

# %%
data3 = ot.windsorization(data=data,col='duration',para=para,strategy='both')
data3[255:275]
# Out:
#      age            job   marital          education  default  housing  \
# 255   53       services   married        high.school       no      yes
# 256   58    blue-collar   married           basic.9y  unknown      yes
# 257   45     management   married           basic.9y       no       no
# 258   43     technician   married            unknown       no      yes
# 259   33         admin.   married        high.school       no       no
# 260   33         admin.   married        high.school       no       no
# 261   27    blue-collar    single           basic.6y       no  unknown
# 262   42     technician   married        high.school       no       no
# 263   43         admin.  divorced           basic.9y       no       no
# 264   42         admin.   married  university.degree       no       no
# 265   27    blue-collar    single           basic.6y       no       no
# 266   34  self-employed    single  university.degree       no      yes
# ...

# %%
# Descartar valores atípicos

# %%
index,para = ot.outlier_detect_arbitrary(data,'duration',300,5)
print('Límite superior:',para[0],'\nLímite inferior:',para[1])
# Out:
# Num of outlier detected: 11227
# Proportion of outlier detected 0.2725793920559386
# Límite superior: 300
# Límite inferior: 5

# %%
data4 = ot.drop_outlier(data=data,outlier_index=index)
print(data4.duration.max())
print(data4.duration.min())
# Out:
# 300
# 5

# %%
# Media/mediana/moda

# %%
index,para = ot.outlier_detect_arbitrary(data,'duration',300,5)
print('Límite superior:',para[0],'\nLímite inferior:',para[1])
# Out:
# Num of outlier detected: 11227
# Proportion of outlier detected 0.2725793920559386
# Límite superior: 300
# Límite inferior: 5

# %%
data5 = ot.impute_outlier_with_avg(data=data,col='duration',
                                   outlier_index=index,strategy='mean')
data5[255:275]
# Out:
#      age            job   marital          education  default  housing  \
# 255   53       services   married        high.school       no      yes
# 256   58    blue-collar   married           basic.9y  unknown      yes
# 257   45     management   married           basic.9y       no       no
# 258   43     technician   married            unknown       no      yes
# 259   33         admin.   married        high.school       no       no
# 260   33         admin.   married        high.school       no       no
# 261   27    blue-collar    single           basic.6y       no  unknown
# 262   42     technician   married        high.school       no       no
# 263   43         admin.  divorced           basic.9y       no       no
# 264   42         admin.   married  university.degree       no       no
# 265   27    blue-collar    single           basic.6y       no       no
# 266   34  self-employed    single  university.degree       no      yes
# ...
