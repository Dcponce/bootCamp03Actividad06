# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os plt.style.use('seaborn-v0_8-colorblind')
# %matplotlib inline
from data_exploration import explore

# %%
#Read the dataset

# %%
use_cols = [
    'age', 'job', 'marital', 'contact', 'day_of_week',
    'housing','poutcome'
]

data = pd.read_csv('./data/bank-additional-full.csv', sep=';', usecols=use_cols)

# %%
data.head(3)
# Out:
#    age        job  marital housing    contact day_of_week     poutcome
# 0   56  housemaid  married      no  telephone         mon  nonexistent
# 1   57   services  married      no  telephone         mon  nonexistent
# 2   37   services  married     yes  telephone         mon  nonexistent

# %%
#Tipos de datos por columna

# %%
str_var_list, num_var_list, all_var_list = explore.get_dtypes(data=data)

# %%
print(str_var_list) # string type
print(num_var_list) # numeric type
print(all_var_list) # all
# Out:
# ['job', 'marital', 'housing', 'contact', 'day_of_week', 'poutcome']
# ['age']
# ['job', 'marital', 'housing', 'contact', 'day_of_week', 'poutcome', 'age']

# %%
#General data description

# %%
explore.describe(data=data,output_path=r'./output/')
# Out:
# result saved at: ./output/describe.csv
#                 age     job  marital housing   contact day_of_week  \
# count   41188.00000   41188    41188   41188     41188       41188
# unique          NaN      12        4       3         2           5
# top             NaN  admin.  married     yes  cellular         thu
# freq            NaN   10422    24928   21576     26144        8623
# mean       40.02406     NaN      NaN     NaN       NaN         NaN
# std        10.42125     NaN      NaN     NaN       NaN         NaN
# min        17.00000     NaN      NaN     NaN       NaN         NaN
# 25%        32.00000     NaN      NaN     NaN       NaN         NaN
# 50%        38.00000     NaN      NaN     NaN       NaN         NaN
# 75%        47.00000     NaN      NaN     NaN       NaN         NaN
# max        98.00000     NaN      NaN     NaN       NaN         NaN
#
#            poutcome
# count         41188
# unique            3
# top     nonexistent
# freq          35563
# mean            NaN
# std             NaN
# min             NaN
# 25%             NaN
# 50%             NaN
# 75%             NaN
# max             NaN

# %%
#Gráfico de barras

# %%
explore.discrete_var_barplot(x='job',y='age',data=data,output_path='./output/')
# Out:
# Image saved at ./output/Barplot_job_age.png

# %%
#Bloxpot

# %%
explore.discrete_var_boxplot(x='marital',y='age',data=data,output_path='./output/')
# Out:
# Image saved at ./output/Boxplot_marital_age.png

# %%
#Continuous variable distplot

# %%
explore.continuous_var_distplot(x=data['age'],output_path='./output/')
# Out:
# Image saved at ./output/Distplot_age.png

# %%
#Diagrama de dispersión

# %%
explore.scatter_plot(x=data.age,y=data.marital,data=data,output_path='./output/')
# Out:
# Image saved at ./output/Scatter_plot_age_marital.png
